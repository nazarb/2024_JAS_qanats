# %%
# Set working area

# %%
cd C:\ML\yolov9
# Out:
# C:\ML\yolov9

# %%
# import libraries

# %%
import ultralytics
ultralytics.checks()

import torch
import torchvision
import os
import logging
import shutil
logging.getLogger().setLevel(logging.CRITICAL)
from ultralytics import YOLO

from IPython.display import Image, clear_output  # to display images
os.environ['KMP_DUPLICATE_LIB_OK']='True'
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Setup complete ✅ (20 CPUs, 63.7 GB RAM, 380.3/475.8 GB disk)
# Setup complete. Using torch 2.0.1 (NVIDIA GeForce RTX 3060)

# %%
cd C:\ML\yolov9
# Out:
# C:\ML\yolov9

# %% [markdown]
# # Train

# %%
# !python train_dual.py --device 0 --workers 8 --batch 32 --img 256 --epochs 200 --data c:/ml/yolov9/Datasets/qanats_256_synt_G1_AFG1_pairs_single_2.yaml --weights c:/ml/yolov9/Datasets/yolov9-e.pt --cfg c:/ml/yolov9/models/detect/yolov9_qanat.yaml --hyp c:/ml/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# train_dual: weights=c:/ml/yolov9/Datasets/yolov9-e.pt, cfg=c:/ml/yolov9/models/detect/yolov9_qanat.yaml, data=c:/ml/yolov9/Datasets/qanats_256_synt_G1_AFG1_pairs_single_2.yaml, hyp=c:/ml/yolov9/data/hyps/hyp.scratch-high.yaml, epochs=200, batch_size=32, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, obj=0.7, obj_pw=1.0, dfl=1.5, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO  in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1         0  models.common.Silence                   []
#   1                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   2                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   3                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   4                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#   5                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   6                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#   7                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   8                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#   9                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#  10                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 7]  1         0  models.common.Concat                    [1]
#  13                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  14                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  15           [-1, 5]  1         0  models.common.Concat                    [1]
#  16                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  17                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  18          [-1, 13]  1         0  models.common.Concat                    [1]
#  19                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  20                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  21          [-1, 10]  1         0  models.common.Concat                    [1]
#  22                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  23                 5  1    131328  models.common.CBLinear                  [512, [256]]
#  24                 7  1    393984  models.common.CBLinear                  [512, [256, 512]]
#  25                 9  1    656640  models.common.CBLinear                  [512, [256, 512, 512]]
#  26                 0  1      1856  models.common.Conv                      [3, 64, 3, 2]
#  27                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#  28                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#  29                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  30  [23, 24, 25, -1]  1         0  models.common.CBFuse                    [[0, 0, 0]]
#  31                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#  32                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  33      [24, 25, -1]  1         0  models.common.CBFuse                    [[1, 1]]
#  34                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#  35                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  36          [25, -1]  1         0  models.common.CBFuse                    [[2]]
#  37                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#  38[31, 34, 37, 16, 19, 22]  1  21545132  models.yolo.DualDDetect                 [2, [512, 512, 512, 256, 512, 512]]
# yolov9_qanat summary: 930 layers, 60799532 parameters, 60799500 gradients, 266.1 GFLOPs
#
# Transferred 438/1412 items from c:\ml\yolov9\Datasets\yolov9-e.pt
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 230 weight(decay=0.0), 247 weight(decay=0.0005), 245 bias
# albumentations: MedianBlur(p=0.01, blur_limit=(3, 7)), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8)), RandomBrightnessContrast(p=0.01, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), brightness_by_max=True), RandomGamma(p=0.01, gamma_limit=(80, 120), eps=None), ImageCompression(p=0.01, quality_lower=75, quality_upper=100, compression_type=0), Downscale(p=0.5, scale_min=0.25, scale_max=0.25), Emboss(p=0.5, alpha=(0.2, 0.5), strength=(0.2, 0.7)), GaussNoise(p=0.5, var_limit=(10.0, 50.0), per_channel=True, mean=0), Perspective(p=0.5, scale=(0.06, 0.1), keep_size=True, pad_mode=0, pad_val=0, mask_pad_val=0, fit_output=False, interpolation=1)
#
# train: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\train.cache... 4710 images, 1298 backgrounds, 0 corrupt: 100%|##########| 4710/4710 00:00
# train: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\train.cache... 4710 images, 1298 backgrounds, 0 corrupt: 100%|##########| 4710/4710 00:00
#
# val: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\val.cache... 589 images, 172 backgrounds, 0 corrupt: 100%|##########| 589/589 00:00
# val: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\val.cache... 589 images, 172 backgrounds, 0 corrupt: 100%|##########| 589/589 00:00
# Plotting labels to runs\train\exp\labels.jpg...
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to runs\train\exp
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#   0%|          | 0/148 00:00
#       0/199      6.23G      7.641      5.593      5.285        663        256:   0%|          | 0/148 00:01WARNING  TensorBoard graph visualization failure Only tensors, lists, tuples of tensors, or dictionary of tensors can be output from traced functions
#
#       0/199      6.23G      7.641      5.593      5.285        663        256:   1%|          | 1/148 00:05
#       0/199       6.6G      7.054      5.357      5.309        987        256:   1%|          | 1/148 00:06
#       0/199       6.6G      7.054      5.357      5.309        987        256:   1%|1         | 2/148 00:06
#       0/199      6.97G      6.743      5.309      5.308       1138        256:   1%|1         | 2/148 00:06
#       0/199      6.97G      6.743      5.309      5.308       1138        256:   2%|2         | 3/148 00:06
#       0/199      7.35G      6.935      5.287      5.311       1093        256:   2%|2         | 3/148 00:07
#       0/199      7.35G      6.935      5.287      5.311       1093        256:   3%|2         | 4/148 00:07
#       0/199      7.77G      6.824       5.29      5.317        769        256:   3%|2         | 4/148 00:07
#       0/199      7.77G      6.824       5.29      5.317        769        256:   3%|3         | 5/148 00:07
#       0/199      8.33G      6.767      5.258      5.317       1194        256:   3%|3         | 5/148 00:08
#       0/199      8.33G      6.767      5.258      5.317       1194        256:   4%|4         | 6/148 00:08
#       0/199      8.33G        6.6      5.255       5.31        789        256:   4%|4         | 6/148 00:08
#       0/199      8.33G        6.6      5.255       5.31        789        256:   5%|4         | 7/148 00:08
#       0/199      8.33G      6.541      5.276      5.312        925        256:   5%|4         | 7/148 00:09
#       0/199      8.33G      6.541      5.276      5.312        925        256:   5%|5         | 8/148 00:09
#       0/199      8.33G      6.515       5.26      5.312        551        256:   5%|5         | 8/148 00:09
#       0/199      8.33G      6.515       5.26      5.312        551        256:   6%|6         | 9/148 00:09
#       0/199      8.33G      6.392      5.246      5.315        898        256:   6%|6         | 9/148 00:10
#       0/199      8.33G      6.392      5.246      5.315        898        256:   7%|6         | 10/148 00:10
#       0/199      8.33G      6.374      5.255      5.314        596        256:   7%|6         | 10/148 00:11
#       0/199      8.33G      6.374      5.255      5.314        596        256:   7%|7         | 11/148 00:11
#       0/199         9G      6.388      5.243      5.313       1119        256:   7%|7         | 11/148 00:11
#       0/199         9G      6.388      5.243      5.313       1119        256:   8%|8         | 12/148 00:11
#       0/199         9G      6.451      5.275      5.309        702        256:   8%|8         | 12/148 00:12
#       0/199         9G      6.451      5.275      5.309        702        256:   9%|8         | 13/148 00:12
#       0/199         9G      6.443      5.263      5.306        881        256:   9%|8         | 13/148 00:12
#       0/199         9G      6.443      5.263      5.306        881        256:   9%|9         | 14/148 00:12
#       0/199         9G      6.492       5.26      5.304        847        256:   9%|9         | 14/148 00:13
#       0/199         9G      6.492       5.26      5.304        847        256:  10%|#         | 15/148 00:13
#       0/199         9G      6.512      5.254      5.303        938        256:  10%|#         | 15/148 00:13
#       0/199         9G      6.512      5.254      5.303        938        256:  11%|#         | 16/148 00:13
#       0/199         9G      6.526      5.252      5.301        776        256:  11%|#         | 16/148 00:14
#       0/199         9G      6.526      5.252      5.301        776        256:  11%|#1        | 17/148 00:14
#       0/199         9G       6.55      5.248        5.3        872        256:  11%|#1        | 17/148 00:14
#       0/199         9G       6.55      5.248        5.3        872        256:  12%|#2        | 18/148 00:14
#       0/199         9G      6.525       5.24        5.3        780        256:  12%|#2        | 18/148 00:15
#       0/199         9G      6.525       5.24        5.3        780        256:  13%|#2        | 19/148 00:15
#       0/199         9G      6.542      5.241      5.301        906        256:  13%|#2        | 19/148 00:15
#       0/199      9.83G      6.359      4.633      5.026        827        256:  98%|#########7| 145/148 01:13
#       0/199      9.83G      6.359      4.633      5.026        827        256:  99%|#########8| 146/148 01:13
#       0/199      9.83G      6.352      4.632      5.024        827        256:  99%|#########8| 146/148 01:13
#       0/199      9.83G      6.352      4.632      5.024        827        256:  99%|#########9| 147/148 01:13
#       0/199      9.91G      6.347      4.628      5.021        161        256:  99%|#########9| 147/148 01:14
#       0/199      9.91G      6.347      4.628      5.021        161        256: 100%|##########| 148/148 01:14
#       0/199      9.91G      6.347      4.628      5.021        161        256: 100%|##########| 148/148 01:14
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/10 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  10%|#         | 1/10 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20%|##        | 2/10 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  30%|###       | 3/10 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|####      | 4/10 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 5/10 00:02
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|######    | 6/10 00:02
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  70%|#######   | 7/10 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  80%|########  | 8/10 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  90%|######### | 9/10 00:04
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:04
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:04
#                    all        589       9080    0.00159     0.0652    0.00195   0.000621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#   0%|          | 0/148 00:00
#       1/199      9.91G      5.873       4.03      4.586       1091        256:   0%|          | 0/148 00:00
#       1/199      9.91G      5.873       4.03      4.586       1091        256:   1%|          | 1/148 00:00
#       1/199      9.91G      5.826      3.915      4.549        779        256:   1%|          | 1/148 00:00
#       1/199      9.91G      5.826      3.915      4.549        779        256:   1%|1         | 2/148 00:00
#       1/199      9.91G      5.735      3.879      4.544        695        256:   1%|1         | 2/148 00:01
#       1/199      9.91G      5.735      3.879      4.544        695        256:   2%|2         | 3/148 00:01
#       1/199      9.91G      5.748       3.98       4.54        914        256:   2%|2         | 3/148 00:01
#       1/199      9.91G      5.748       3.98       4.54        914        256:   3%|2         | 4/148 00:01
#       1/199      9.91G      5.839      3.987      4.518        839        256:   3%|2         | 4/148 00:02
#       1/199      9.91G      5.839      3.987      4.518        839        256:   3%|3         | 5/148 00:02
#       1/199      9.91G      5.796      3.946      4.517        896        256:   3%|3         | 5/148 00:02
#       1/199      9.91G      5.796      3.946      4.517        896        256:   4%|4         | 6/148 00:02
#       1/199      9.91G      5.763      3.902       4.52        970        256:   4%|4         | 6/148 00:03
#       1/199      9.91G      5.763      3.902       4.52        970        256:   5%|4         | 7/148 00:03
#       1/199      9.91G      5.787      3.883      4.512        980        256:   5%|4         | 7/148 00:03
#       1/199      9.91G      5.787      3.883      4.512        980        256:   5%|5         | 8/148 00:03
#       1/199      9.91G      5.799      3.854      4.498        835        256:   5%|5         | 8/148 00:04
#       1/199      9.91G      5.799      3.854      4.498        835        256:   6%|6         | 9/148 00:04
#       1/199      9.91G       5.79      3.846       4.49        930        256:   6%|6         | 9/148 00:04
#       1/199      9.91G       5.79      3.846       4.49        930        256:   7%|6         | 10/148 00:04
#       1/199      9.91G      5.736      3.835      4.491        782        256:   7%|6         | 10/148 00:04
#       1/199      9.91G      5.736      3.835      4.491        782        256:   7%|7         | 11/148 00:04
#       1/199      9.91G       5.68      3.835        4.5        899        256:   7%|7         | 11/148 00:05
#       1/199      9.91G       5.68      3.835        4.5        899        256:   8%|8         | 12/148 00:05
#       1/199      9.91G      5.642      3.844      4.502        722        256:   8%|8         | 12/148 00:05
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/10 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  10%|#         | 1/10 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20%|##        | 2/10 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  30%|###       | 3/10 00:02
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|####      | 4/10 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 5/10 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|######    | 6/10 00:04
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  70%|#######   | 7/10 00:05
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  80%|########  | 8/10 00:05
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  90%|######### | 9/10 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:06
#                    all        589       9080      0.896      0.864      0.924      0.505
#
# 200 epochs completed in 4.613 hours.
# Optimizer stripped from runs\train\exp\weights\last.pt, 122.3MB
# Optimizer stripped from runs\train\exp\weights\best.pt, 122.3MB
#
# Validating runs\train\exp\weights\best.pt...
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/10 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  10%|#         | 1/10 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20%|##        | 2/10 00:02
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  30%|###       | 3/10 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|####      | 4/10 00:04
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  50%|#####     | 5/10 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|######    | 6/10 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  70%|#######   | 7/10 00:07
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  80%|########  | 8/10 00:08
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  90%|######### | 9/10 00:08
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:09
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 10/10 00:09
#                    all        589       9080      0.896      0.864      0.924      0.505
#                  qanat        589       4931      0.905      0.854      0.916       0.47
#             qanat_pair        589       4149      0.888      0.875      0.932       0.54
# Results saved to runs\train\exp

# %%
# Validation

# %%
# !python val_dual.py --data c:/ml/yolov9/Datasets/qanats_256_synt_G1_AFG1_pairs_single_2.yaml --img 256 --batch 32 --conf 0.001 --iou 0.7 --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --save-json --name yolov9_e_256_val  --device 0
# Out:
# loading annotations into memory...
# val_dual: data=c:/ml/yolov9/Datasets/qanats_256_synt_G1_AFG1_pairs_single_2.yaml, weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=256, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs\val, name=yolov9_e_256_val, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
#
# val: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\val.cache... 589 images, 172 backgrounds, 0 corrupt: 100%|##########| 589/589 00:00
# val: Scanning C:\ML\datasets\qanats_256_synt_G1_AFG1_pairs_single_2\labels\val.cache... 589 images, 172 backgrounds, 0 corrupt: 100%|##########| 589/589 00:00
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/19 00:00
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   5%|5         | 1/19 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  11%|#         | 2/19 00:01
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  16%|#5        | 3/19 00:02
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  21%|##1       | 4/19 00:03
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  26%|##6       | 5/19 00:04
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  32%|###1      | 6/19 00:05
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  37%|###6      | 7/19 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  42%|####2     | 8/19 00:06
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  47%|####7     | 9/19 00:07
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  53%|#####2    | 10/19 00:07
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  58%|#####7    | 11/19 00:08
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  63%|######3   | 12/19 00:08
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  68%|######8   | 13/19 00:09
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  74%|#######3  | 14/19 00:09
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  79%|#######8  | 15/19 00:10
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  84%|########4 | 16/19 00:11
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  89%|########9 | 17/19 00:11
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  95%|#########4| 18/19 00:11
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 19/19 00:12
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 19/19 00:12
#                    all        589       9080      0.895      0.865      0.924      0.505
#                  qanat        589       4931      0.905      0.855      0.916       0.47
#             qanat_pair        589       4149      0.885      0.876      0.932       0.54
# Speed: 0.1ms pre-process, 9.7ms inference, 1.5ms NMS per image at shape (32, 3, 256, 256)
#
# Evaluating pycocotools mAP... saving runs\val\yolov9_e_256_val\best_predictions.json...
# pycocotools unable to run: [Errno 2] No such file or directory: 'C:\\ML\\datasets\\qanats_256_synt_G1_AFG1_pairs_single_2\\annotations\\instances_val2017.json'
# Results saved to runs\val\yolov9_e_256_val

# %%
# !tensorboard --logdir runs\train
# Out:
# ^C

# %% [markdown]
# # Save

# %%
# Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.200  Python-3.11.3 torch-2.0.1 CPU (12th Gen Intel Core(TM) i7-12700)
#
# PyTorch: starting from 'c:\ML\ultralytics\runs\detect\qanats_256_synt_pairs_single_3c_\weights\best.pt' with input shape (1, 3, 256, 256) BCHW and output shape(s) (1, 6, 1344) (130.4 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success  4.9s, saved as 'c:\ML\ultralytics\runs\detect\qanats_256_synt_pairs_single_3c_\weights\best.onnx' (260.0 MB)
#
# Export complete (9.1s)
# Results saved to C:\ML\ultralytics\runs\detect\qanats_256_synt_pairs_single_3c_\weights
# Predict:         yolo predict task=detect model=c:\ML\ultralytics\runs\detect\qanats_256_synt_pairs_single_3c_\weights\best.onnx imgsz=256
# Validate:        yolo val task=detect model=c:\ML\ultralytics\runs\detect\qanats_256_synt_pairs_single_3c_\weights\best.onnx imgsz=256 data=qanats_256_synt_G1_AFG1_pairs_single_2.yaml
# Visualize:       https://netron.app
# 'c:\\ML\\ultralytics\\runs\\detect\\qanats_256_synt_pairs_single_3c_\\weights\\best.onnx'

# %% [markdown]
# # Detect

# %% [raw]
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
#                  [--data DATA] [--imgsz IMGSZ [IMGSZ ...]]
#                  [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img]
#                  [--save-txt] [--save-conf] [--save-crop] [--nosave]
#                  [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS]
#                  [--hide-labels] [--hide-conf] [--half] [--dnn]
#                  [--vid-stride VID_STRIDE]
# detect.py: error: argument --imgsz/--img/--img-size: invalid int value: 'show_labels=False'

# %% [markdown]
# ## Morroco

# %%
#runs\detect\exp ## D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif

# %%
## 1211

# %%
# !python detect.py --device 0 --img 4096 --conf 0.1 --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --source D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif
# Out:
# requirements: C:\ML\yolov9\requirements.txt not found, check failed.
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif, data=data\coco128.yaml, imgsz=[4096, 4096], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR1\D3C1211-100139A008_ij_clip7_b1_ab.tif: 4096x4096 501 qanats, 499 qanat_pairs, 1398.3ms
# Speed: 7.5ms pre-process, 1398.3ms inference, 62.1ms NMS per image at shape (1, 3, 4096, 4096)
# Results saved to runs\detect\exp

# %%
# runs\detect\exp2 - D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif --img 4096 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# requirements: C:\ML\yolov9\requirements.txt not found, check failed.
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_ab.tif, data=data\coco128.yaml, imgsz=[4096, 4096], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR1\D3C1211-100139A008_ij_clip7_b1_ab.tif: 4096x4096 658 qanats, 629 qanat_pairs, 1396.6ms
# Speed: 7.6ms pre-process, 1396.6ms inference, 50.0ms NMS per image at shape (1, 3, 4096, 4096)
# Results saved to runs\detect\exp2
# 1 labels saved to runs\detect\exp2\labels

# %%
# runs\detect\exp15 - D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_a.tif - runs\detect\exp15

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_a.tif --img 4096 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1_a.tif, data=data\coco128.yaml, imgsz=[4096, 4096], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR1\D3C1211-100139A008_ij_clip7_b1_a.tif: 4096x4096 2671 qanats, 2595 qanat_pairs, 1393.5ms
# Speed: 8.0ms pre-process, 1393.5ms inference, 83.3ms NMS per image at shape (1, 3, 4096, 4096)
# Results saved to runs\detect\exp15
# 1 labels saved to runs\detect\exp15\labels

# %%
#runs\detect\exp16 - D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1.tif

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1.tif --img 9216 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:/UnderTheSand/Rasters/ML/MR1/D3C1211-100139A008_ij_clip7_b1.tif, data=data\coco128.yaml, imgsz=[9216, 9216], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR1\D3C1211-100139A008_ij_clip7_b1.tif: 9216x6720 4685 qanats, 4622 qanat_pairs, 66199.6ms
# Speed: 41.7ms pre-process, 66199.6ms inference, 127.6ms NMS per image at shape (1, 3, 9216, 9216)
# Results saved to runs\detect\exp16
# 1 labels saved to runs\detect\exp16\labels

# %%
##1218

# %%
# D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_ad.tif - runs\detect\exp12\labels

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_ad.tif --img 3072 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_ad.tif, data=data\coco128.yaml, imgsz=[3072, 3072], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_ad.tif: 3072x3072 1930 qanats, 1870 qanat_pairs, 789.3ms
# Speed: 5.0ms pre-process, 789.3ms inference, 99.5ms NMS per image at shape (1, 3, 3072, 3072)
# Results saved to runs\detect\exp12
# 1 labels saved to runs\detect\exp12\labels

# %%
# D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_a.tif - runs\detect\exp13\labels

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_a.tif --img 4096 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_a.tif, data=data\coco128.yaml, imgsz=[4096, 4096], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8_a.tif: 4096x4096 3211 qanats, 3086 qanat_pairs, 1395.1ms
# Speed: 7.5ms pre-process, 1395.1ms inference, 75.8ms NMS per image at shape (1, 3, 4096, 4096)
# Results saved to runs\detect\exp13
# 1 labels saved to runs\detect\exp13\labels

# %%
# D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8.tif

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8.tif --img 9216 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8.tif, data=data\coco128.yaml, imgsz=[9216, 9216], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\MR2b\D3C1218-401390F004_bc_8\D3C1218-401390F004_bc_8.tif: 9216x9216 4001 qanats, 3980 qanat_pairs, 118320.9ms
# Speed: 58.6ms pre-process, 118320.9ms inference, 109.4ms NMS per image at shape (1, 3, 9216, 9216)
# Results saved to runs\detect\exp14
# 1 labels saved to runs\detect\exp14\labels

# %% [markdown]
# ## Gorgan

# %%
#runs\detect\exp5-6 #D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif - is better

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif --img 5632 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif, data=data\coco128.yaml, imgsz=[5632, 5632], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif: 3552x5632 1981 qanats, 2217 qanat_pairs, 9712.2ms
# Speed: 13.6ms pre-process, 9712.2ms inference, 99.9ms NMS per image at shape (1, 3, 5632, 5632)
# Results saved to runs\detect\exp5
# 1 labels saved to runs\detect\exp5\labels

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif --img 9216 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif, data=data\coco128.yaml, imgsz=[9216, 9216], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\G1\D3C1216-401091A016_a\A016_a3.tif: 5792x9216 2748 qanats, 2435 qanat_pairs, 54370.5ms
# Speed: 40.6ms pre-process, 54370.5ms inference, 73.3ms NMS per image at shape (1, 3, 9216, 9216)
# Results saved to runs\detect\exp6
# 1 labels saved to runs\detect\exp6\labels

# %%
# D:\UnderTheSand\Rasters\ML\G1\D3C1219-10139\D3C1219_a3.tif - runs\detect\exp9

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\G1\D3C1219-10139\D3C1219_a3.tif --img 9216 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\G1\D3C1219-10139\D3C1219_a3.tif, data=data\coco128.yaml, imgsz=[9216, 9216], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\G1\D3C1219-10139\D3C1219_a3.tif: 7264x9216 1382 qanats, 1268 qanat_pairs, 64618.1ms
# Speed: 43.5ms pre-process, 64618.1ms inference, 133.9ms NMS per image at shape (1, 3, 9216, 9216)
# Results saved to runs\detect\exp9
# 1 labels saved to runs\detect\exp9\labels

# %%
#runs\detect\exp4#D:\UnderTheSand\Rasters\ML\G2\ds1110-1089df038_wgs_1_a.tif

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\G2\ds1110-1089df038_wgs_1_a.tif --img 2048 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\G2\ds1110-1089df038_wgs_1_a.tif, data=data\coco128.yaml, imgsz=[2048, 2048], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\G2\ds1110-1089df038_wgs_1_a.tif: 1632x2048 550 qanats, 512 qanat_pairs, 317.3ms
# Speed: 0.0ms pre-process, 317.3ms inference, 140.1ms NMS per image at shape (1, 3, 2048, 2048)
# Results saved to runs\detect\exp4
# 1 labels saved to runs\detect\exp4\labels

# %%
## Afghanistan

# %%
## runs\detect\exp10 -  D:\UnderTheSand\Rasters\ML\AFG1\D3C1219-300971A040_c_10.tif: 5120x5120 (yolov 8) - try 8192

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\AFG1\D3C1219-300971A040_c_10.tif --img 8192 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\AFG1\D3C1219-300971A040_c_10.tif, data=data\coco128.yaml, imgsz=[8192, 8192], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\AFG1\D3C1219-300971A040_c_10.tif: 8192x8192 794 qanats, 758 qanat_pairs, 65074.3ms
# Speed: 48.2ms pre-process, 65074.3ms inference, 154.2ms NMS per image at shape (1, 3, 8192, 8192)
# Results saved to runs\detect\exp10
# 1 labels saved to runs\detect\exp10\labels

# %%
##  D:\UnderTheSand\Rasters\ML\AFG1\D3C1209-300484A022_a_10.tif: 5120x5120 (yolov)	3102

# %%
# !python detect.py --weights C:/ML/yolov9/runs/train/exp/weights/best.pt --conf 0.1 --source D:\UnderTheSand\Rasters\ML\AFG1\D3C1209-300484A022_a_10.tif --img 4096 --save-txt --save-conf --max-det 9999999999 --device 0
# Out:
# detect: weights=['C:/ML/yolov9/runs/train/exp/weights/best.pt'], source=D:\UnderTheSand\Rasters\ML\AFG1\D3C1209-300484A022_a_10.tif, data=data\coco128.yaml, imgsz=[4096, 4096], conf_thres=0.1, iou_thres=0.45, max_det=9999999999, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v0.1-28-g8a17325 Python-3.11.3 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# yolov9_qanat summary: 580 layers, 60498220 parameters, 0 gradients, 263.9 GFLOPs
# image 1/1 D:\UnderTheSand\Rasters\ML\AFG1\D3C1209-300484A022_a_10.tif: 4096x4096 701 qanats, 669 qanat_pairs, 1400.0ms
# Speed: 8.5ms pre-process, 1400.0ms inference, 147.9ms NMS per image at shape (1, 3, 4096, 4096)
# Results saved to runs\detect\exp11
# 1 labels saved to runs\detect\exp11\labels

# %%
## Yollo v8
